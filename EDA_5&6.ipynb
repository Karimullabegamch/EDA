# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv("/home/karimulla/Desktop/Python-ws/IPL_2025_Player_Stats_Updated.csv")
ipl
# Out:
#             Player                         Team  Matches  Runs  Wickets  \
# 0     Rishabh Pant               Delhi Capitals       20  1899       90
# 1         MS Dhoni          Chennai Super Kings       40  1957       48
# 2     Sanju Samson             Rajasthan Royals       22   393       78
# 3    Hardik Pandya               Mumbai Indians       12   208       81
# 4      Virat Kohli  Royal Challengers Bangalore       48   146       25
# ..             ...                          ...      ...   ...      ...
# 495     Player_496  Royal Challengers Bangalore       37   720        1
# 496     Player_497               Delhi Capitals       48  1960       68
# 497     Player_498               Delhi Capitals       35   925       65
# 498     Player_499               Mumbai Indians       29   573       69
# 499     Player_500  Royal Challengers Bangalore        3    98       44
#
#      Strike Rate  Economy Rate  Catches  Stumpings
# 0         125.44         11.37       10          5
# ...

# %%
ipl.corr(numeric_only=True)
# Out:
#                Matches      Runs   Wickets  Strike Rate  Economy Rate  \
# Matches       1.000000 -0.012731 -0.035114    -0.068119      0.059111
# Runs         -0.012731  1.000000 -0.011387     0.032080      0.032110
# Wickets      -0.035114 -0.011387  1.000000     0.020525      0.009497
# Strike Rate  -0.068119  0.032080  0.020525     1.000000     -0.021609
# Economy Rate  0.059111  0.032110  0.009497    -0.021609      1.000000
# Catches       0.075235 -0.009081  0.037365    -0.093807     -0.069811
# Stumpings     0.090732  0.034714  0.013450    -0.060861      0.030884
#
#                Catches  Stumpings
# Matches       0.075235   0.090732
# Runs         -0.009081   0.034714
# Wickets       0.037365   0.013450
# Strike Rate  -0.093807  -0.060861
# Economy Rate -0.069811   0.030884
# Catches       1.000000   0.076986
# Stumpings     0.076986   1.000000

# %%
sns.heatmap(ipl.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()


ipl['Team']=le.fit_transform(ipl['Team'])
ipl['Team'].value_counts()
# Out:
# Team
# 1    73
# 3    73
# 0    68
# 6    66
# 7    59
# 4    54
# 2    54
# 5    53
# Name: count, dtype: int64

# %%
pd.get_dummies(ipl['Team'],columns=[ipl['Team'].unique()])
# Out:
#          0      1      2      3      4      5      6      7
# 0    False   True  False  False  False  False  False  False
# 1     True  False  False  False  False  False  False  False
# 2    False  False  False  False  False   True  False  False
# 3    False  False  False   True  False  False  False  False
# 4    False  False  False  False  False  False   True  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 495  False  False  False  False  False  False   True  False
# 496  False   True  False  False  False  False  False  False
# 497  False   True  False  False  False  False  False  False
# 498  False  False  False   True  False  False  False  False
# 499  False  False  False  False  False  False   True  False
#
# [500 rows x 8 columns]

# %%
ipl=pd.read_csv("/home/karimulla/Desktop/Python-ws/IPL_2025_Player_Stats_Updated.csv")
ipl
# Out:
#             Player                         Team  Matches  Runs  Wickets  \
# 0     Rishabh Pant               Delhi Capitals       20  1899       90
# 1         MS Dhoni          Chennai Super Kings       40  1957       48
# 2     Sanju Samson             Rajasthan Royals       22   393       78
# 3    Hardik Pandya               Mumbai Indians       12   208       81
# 4      Virat Kohli  Royal Challengers Bangalore       48   146       25
# ..             ...                          ...      ...   ...      ...
# 495     Player_496  Royal Challengers Bangalore       37   720        1
# 496     Player_497               Delhi Capitals       48  1960       68
# 497     Player_498               Delhi Capitals       35   925       65
# 498     Player_499               Mumbai Indians       29   573       69
# 499     Player_500  Royal Challengers Bangalore        3    98       44
#
#      Strike Rate  Economy Rate  Catches  Stumpings
# 0         125.44         11.37       10          5
# ...

# %%
pd.get_dummies(ipl['Team'],dtype='int')
# Out:
#      Chennai Super Kings  Delhi Capitals  Kolkata Knight Riders  \
# 0                      0               1                      0
# 1                      1               0                      0
# 2                      0               0                      0
# 3                      0               0                      0
# 4                      0               0                      0
# ..                   ...             ...                    ...
# 495                    0               0                      0
# 496                    0               1                      0
# 497                    0               1                      0
# 498                    0               0                      0
# 499                    0               0                      0
#
#      Mumbai Indians  Punjab Kings  Rajasthan Royals  \
# 0                 0             0                 0
# 1                 0             0                 0
# ...

# %%
ipl=pd.read_csv("/home/karimulla/Desktop/Python-ws/IPL_2025_Player_Stats_Updated.csv")
min_r=ipl['Runs'].min()
max_r=ipl['Runs'].max()
dr=max_r-min_r
nr=ipl['Runs']-min_r
ipl['runs_norm']=dr/nr
ipl
# Out:
#             Player                         Team  Matches  Runs  Wickets  \
# 0     Rishabh Pant               Delhi Capitals       20  1899       90
# 1         MS Dhoni          Chennai Super Kings       40  1957       48
# 2     Sanju Samson             Rajasthan Royals       22   393       78
# 3    Hardik Pandya               Mumbai Indians       12   208       81
# 4      Virat Kohli  Royal Challengers Bangalore       48   146       25
# ..             ...                          ...      ...   ...      ...
# 495     Player_496  Royal Challengers Bangalore       37   720        1
# 496     Player_497               Delhi Capitals       48  1960       68
# 497     Player_498               Delhi Capitals       35   925       65
# 498     Player_499               Mumbai Indians       29   573       69
# 499     Player_500  Royal Challengers Bangalore        3    98       44
#
#      Strike Rate  Economy Rate  Catches  Stumpings  runs_norm
# ...

# %%
ipl['runs_norm'].min(),ipl['runs_norm'].max()
# Out:
# (1.0, inf)

# %%
ipl['Runs'].min(),ipl['Runs'].max()
# Out:
# (2, 1999)

# %%
ipl['runs_norm'].idxmin(),ipl['runs_norm'].idxmax()
# Out:
# (219, 170)

# %%
ipl[['Runs']].iloc[[219,170]]
# Out:
#      Runs
# 219  1999
# 170     2

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
mms.fit_transform(ipl[['Runs']])
# Out:
# array([[0.94992489],
#        [0.97896845],
#        [0.19579369],
#        [0.10315473],
#        [0.07210816],
#        [0.27040561],
#        [0.50625939],
#        [0.53129695],
#        [0.18828242],
#        [0.66249374],
#        [0.23435153],
#        [0.56935403],
#        [0.74361542],
#        [0.7991988 ],
#        [0.21482223],
#        [0.55232849],
#        [0.3995994 ],
#        [0.4221332 ],
#        [0.49724587],
#        [0.15623435],
#        [0.20580871],
#        [0.35302954],
#        [0.61141713],
#        [0.38908363],
#        [0.18978468],
#        [0.11116675],
#        [0.70856284],
#        [0.21131698],
#        [0.50275413],
#        [0.03405108],
#        [0.01702554],
#        [0.8432649 ],
#        [0.18828242],
#        [0.34051077],
#        [0.59038558],
#        [0.7315974 ],
#        [0.31797697],
#        [0.36955433],
#        [0.2879319 ],
#        [0.14722083],
#        [0.25237857],
#        [0.97295944],
#        [0.8452679 ],
# ...
